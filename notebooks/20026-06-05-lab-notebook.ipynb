# %% [markdown]
# Goal: test basic functions (count, disease_percentage) and load a real dataset.
#
# ##Environment Setup
# This notebook uses pandas, numpy, and functions from src/cells.py.
#
# We will first test the function on simple made-up test data in list form and a more realistic matrix form.

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append("../src");
"add src folder to Python path so we can import cells.py"
from cells import count, disease_percentage

# %% [markdown]
# ##Test 1: Simple List-Based Dataset
#
# We begin with a simple list of all cell states to confirm that the function on basic input.
# Expected:
# - 4 healthy cells
# - 4 diseased cells
# - 50% diseased

# %%
simple_matrix = ["healthy", "diseased", "healthy", "diseased",
                    "healthy", "diseased", "healthy", "diseased"]

print("Simple dataset:", simple_matrix)
print("Healthy count:", count(simple_matrix , "healthy"))
print("Diseased count:", count(simple_matrix, "diseased"))
print("Disease percentage:", disease_percentage(simple_matrix))
print("\n")
# Out:
# Simple dataset: ['healthy', 'diseased', 'healthy', 'diseased', 'healthy', 'diseased', 'healthy', 'diseased']
# Healthy count: 4
# Diseased count: 4
# Disease percentage: 50.0

# %% [markdown]
# ##Test 2: Realistic Dictionary-Based dataset
# Next, I will test the functions on a more realistic dataset where each cell is represented as a dictionary containing gene expression values and a 'state' field.
# Expected:
# - 2 healthy cells
# - 6 diseased cells
# - 75% diseased

# %%
real_matrix = [
   {"geneA": 3.2, "geneB": 0.1, "state": "diseased"},
        {"geneA": 7.8, "geneB": 2.3, "state": "diseased"},
        {"geneA": 1.1, "geneB": 0.5, "state": "diseased"},
        {"geneA": 9.4, "geneB": 3.1, "state": "diseased"},
        {"geneA": 2.5, "geneB": 0.2, "state": "healthy"},
        {"geneA": 8.7, "geneB": 4.0, "state": "diseased"},
        {"geneA": 0.9, "geneB": 0.3, "state": "healthy"},
        {"geneA": 6.5, "geneB": 1.8, "state": "diseased"}
]

print("Realistic dataset (list of dicts): ")
for row in real_matrix:
    print(row)

print("\nHealthy count:", count(real_matrix, "healthy"))
print("Diseased count:", count(real_matrix, "diseased"))
print("Disease percentage:", disease_percentage(real_matrix))
# Out:
# Realistic dataset (list of dicts):
# {'geneA': 3.2, 'geneB': 0.1, 'state': 'diseased'}
# {'geneA': 7.8, 'geneB': 2.3, 'state': 'diseased'}
# {'geneA': 1.1, 'geneB': 0.5, 'state': 'diseased'}
# {'geneA': 9.4, 'geneB': 3.1, 'state': 'diseased'}
# {'geneA': 2.5, 'geneB': 0.2, 'state': 'healthy'}
# {'geneA': 8.7, 'geneB': 4.0, 'state': 'diseased'}
# {'geneA': 0.9, 'geneB': 0.3, 'state': 'healthy'}
# {'geneA': 6.5, 'geneB': 1.8, 'state': 'diseased'}
#
# Healthy count: 2
# Diseased count: 6
# Disease percentage: 75.0

# %% [markdown]
# Both tests produced the expected results
# - The 'count()' function correctly handles both string-based and dictionary based cell representations.
# - The 'disease_percentage()' function correctly computer the proportion of diseased cells
# - These results confirm that the helper functions are ready to be used on real datasets.
#
# Next step: load a real dataset and apply these functions to biological data.
